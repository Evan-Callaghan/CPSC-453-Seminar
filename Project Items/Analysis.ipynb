# %%
import pandas as pd
import numpy as np

recs = pd.read_csv('blockbuster_recommendations.csv')

recs.head()
# Out:
#                    Title      Genre Languages Series or Movie View Rating  \
# 0              Fair Game  Biography    Arabic           Movie       PG-13
# 1              Fair Game      Drama    Arabic           Movie       PG-13
# 2              Fair Game   Thriller    Arabic           Movie       PG-13
# 3  The Dark Knight Rises     Action    Arabic           Movie       PG-13
# 4  The Dark Knight Rises  Adventure    Arabic           Movie       PG-13
#
#    Popularity_Score                            Netflix Link  \
# 0          0.749848  https://www.netflix.com/watch/70119704
# 1          0.749848  https://www.netflix.com/watch/70119704
# 2          0.749848  https://www.netflix.com/watch/70119704
# 3          1.277717  https://www.netflix.com/watch/70213514
# 4          1.277717  https://www.netflix.com/watch/70213514
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt0977855
# 1  https://www.imdb.com/title/tt0977855
# ...

# %%
recs[recs['Title'] == 'Batman Begins'][['Title', 'Languages', 'Rec_1', 'Rec_2', 'Rec_3', 'Rec_4', 'Rec_5']]
# Out:
#                Title Languages                  Rec_1  \
# 6151   Batman Begins   English  The Dark Knight Rises
# 6152   Batman Begins   English  The Dark Knight Rises
# 23195  Batman Begins  Mandarin        The Dark Knight
# 23196  Batman Begins  Mandarin        The Dark Knight
#
#                          Rec_2       Rec_3                  Rec_4  \
# 6151                 Star Trek  Spider-Man  Mission: Impossible 5
# 6152                 Star Trek  Spider-Man  Mission: Impossible 5
# 23195  Mission: Impossible III       Venom  The Forbidden Kingdom
# 23196  Mission: Impossible III       Venom  The Forbidden Kingdom
#
#                                     Rec_5
# 6151   Batman v Superman: Dawn of Justice
# 6152   Batman v Superman: Dawn of Justice
# 23195                    Now You See Me 2
# 23196                    Now You See Me 2

# %%
recs[recs['Title'] == 'Criminal Minds'][['Title', 'Languages', 'Rec_1', 'Rec_2', 'Rec_3', 'Rec_4', 'Rec_5']]
# Out:
#                 Title Languages     Rec_1 Rec_2                        Rec_3  \
# 29571  Criminal Minds   English  Sherlock    24  How to Get Away with Murder
# 29572  Criminal Minds   English  Sherlock    24  How to Get Away with Murder
# 29573  Criminal Minds   English  Sherlock    24  How to Get Away with Murder
# 29574  Criminal Minds   English  Sherlock    24  How to Get Away with Murder
#
#                  Rec_4 Rec_5
# 29571  Sons of Anarchy  NCIS
# 29572  Sons of Anarchy  NCIS
# 29573  Sons of Anarchy  NCIS
# 29574  Sons of Anarchy  NCIS

# %%
recs[recs['Title'] == 'The Office (U.S.)'][['Title', 'Languages', 'Rec_1', 'Rec_2', 'Rec_3', 'Rec_4', 'Rec_5']]
# Out:
#                    Title Languages          Rec_1                 Rec_2  \
# 29679  The Office (U.S.)   English  Schitts Creek  Arrested Development
#
#                       Rec_3      Rec_4     Rec_5
# 29679  Parks and Recreation  Community  New Girl

# %%
movie = pd.read_csv('Movie_Data.csv')

movie.shape
# Out:
# (9425, 29)
